# %% [markdown]
# ### Perguntas de interesse
#
#     1. Qual a eficiência dos tribunais ao longo dos anos? Ele subiu ou desceu?
#     2. A produtividade dos magistrados aumentou por conta de uma maior demanda?
#     3. Os tribunais com mais funcionário possuem mais efetividade?
#     4. Em qual instância está o maior gargalo de tempo?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize']=(15,5)

pd.set_option('display.max_colwidth', None) ## padrão é 50
pd.set_option('display.max_rows', None)

var_cnj = pd.read_csv("/Users/Lucas/Documents/Python-CNJ/Dados CNJ/Variaveis_27-Ago-2019.csv",sep=";", header=0,encoding = "Latin1")
base_cnj = pd.read_csv("/Users/Lucas/Documents/Python-CNJ/Dados CNJ/JN_27-Ago-2019.csv",sep=";", header=0,encoding = "Latin1")
base_cnj.head()

#var_cnj ## utilizei esse comando para ver todas as variáveis disponíveis
# Out:
# /Users/Lucas/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (32,66,84,96,153,289,416,520,737,836,902,905,915,916,917,919,920,988,997,998,1016,1046,1412,1417,1418,1419,1420,1421,1422,1423) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     ano   justica sigla   dsc_tribunal uf_sede uf_abrangida  seq_orgao  \
# 0  2009  Estadual  TJAC      TJ - Acre      AC        Norte          8
# 1  2009  Estadual  TJAL   TJ - Alagoas      AL     Nordeste          9
# 2  2009  Estadual  TJAM  TJ - Amazonas      AM        Norte         10
# 3  2009  Estadual  TJAP     TJ - Amapá      AP        Norte         11
# 4  2009  Estadual  TJBA     TJ - Bahia      BA     Nordeste         12
#
#             gt          pib        h1  ... ips_sus.fisc.penal  \
# 0   3519085437   8342355523    732793  ...        50,67691154
# ...

# %% [markdown]
# Antes de trabalhar com o banco de dados propriamente dito, irei selecionar as variáveis de interesse nesse relatório para que eu possa responder as perguntas propostas.
#
# Nessa análise decidi restringir a analise às varas da justiça estadual, que são as que cuidam de questões não relacionadas a trabalho e eleições.

# %%
var_usadas = ['ano','justica','sigla','munic','pib','uf_sede','uf_abrangida','porte','cn1','cn2','tbaix1','tbaix2'
              ,'mage1','mage2','ipm1','ipm2','k1','k2','pesus1','pesus2','procel1','procel2','reatc1','reat2'
              ,'reatextfisc1','sajudmag1','sajudmag2','scn1','scn2','tc1','tc2','tfaux1','tfaux2']

cnj = base_cnj[var_usadas]
var = var_cnj[var_cnj.sigla.isin(var_usadas)] ## criei esse dataframe apenas para eu poder consultar o que representa cada varíavel sem ter que procura-la enre todas as outras
cnj = cnj[cnj['justica']=='Estadual']

cnj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280 entries, 0 to 856
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           280 non-null    int64
#  1   justica       280 non-null    object
#  2   sigla         280 non-null    object
#  3   munic         280 non-null    object
#  4   pib           280 non-null    object
#  5   uf_sede       280 non-null    object
#  6   uf_abrangida  280 non-null    object
#  7   porte         280 non-null    object
#  8   cn1           280 non-null    object
#  9   cn2           280 non-null    object
#  10  tbaix1        280 non-null    object
#  11  tbaix2        280 non-null    object
#  12  mage1         280 non-null    object
#  13  mage2         280 non-null    object
#  14  ipm1          280 non-null    object
#  15  ipm2          280 non-null    object
#  16  k1            280 non-null    object
#  17  k2            280 non-null    object
# ...

# %% [markdown]
# Todas as variáveis que eu escolhi, tirando o ano, estão como object. Vou separar as variáveis que são númericas e transforma-las na categoria correta.

# %%
var_numerics = ['ano','munic','pib','tbaix1','tbaix2','cn1','cn2'
              ,'mage1','mage2','ipm1','ipm2','k1','k2','pesus1','pesus2','procel1','procel2','reatc1','reat2'
              ,'reatextfisc1','sajudmag1','sajudmag2','scn1','scn2','tc1','tc2','tfaux1','tfaux2']

cnj[var_numerics] = cnj[var_numerics].replace(to_replace="(,)",value=".",regex=True)
cnj[var_numerics] = cnj[var_numerics].apply(pd.to_numeric, errors='coerce')
cnj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280 entries, 0 to 856
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ano           280 non-null    int64
#  1   justica       280 non-null    object
#  2   sigla         280 non-null    object
#  3   munic         140 non-null    float64
#  4   pib           280 non-null    float64
#  5   uf_sede       280 non-null    object
#  6   uf_abrangida  280 non-null    object
#  7   porte         280 non-null    object
#  8   cn1           280 non-null    int64
#  9   cn2           280 non-null    int64
#  10  tbaix1        280 non-null    int64
#  11  tbaix2        280 non-null    int64
#  12  mage1         280 non-null    int64
#  13  mage2         280 non-null    int64
#  14  ipm1          280 non-null    float64
#  15  ipm2          280 non-null    float64
#  16  k1            280 non-null    float64
#  17  k2            280 non-null    float64
# ...

# %%
cnj.describe()
len(cnj.ano.unique())
# Out:
# 10

# %% [raw]
# Respondendo a primeira pergunta, vou gerar um gráfico de linha básico com as prodtividades de cada magistrado ao longo dos anos.
#
# No gráfico abaixo é possível verificar que a produtividade dos magistrados aumentou ao  longo dos anos.

# %%
produtividade = cnj.groupby('ano')['ipm1','ipm2'].mean()

titulo = "Número de  processos médio por Magistrados ao Longo dos Anos"
produtividade.plot(title=titulo,grid=False,legend=True)
# Out:
# /Users/Lucas/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
diff_1 = (produtividade.loc[2018,'ipm1'] - produtividade.loc[2009,'ipm1']).round() 
diff_2 = (produtividade.loc[2018,'ipm2'] - produtividade.loc[2009,'ipm2']).round()

print("Diferença no 1 grau {} \nDiferença no 2 grau {}".format(diff_1,diff_2))
# Out:
# Diferença no 1 grau 201.0
# Diferença no 2 grau 414.0

# %% [markdown]
# Em linhas gerais, a produtividade dos magistrados aumentou. É interessante notar que a produtividade dos Magistrados do 2 grau é menor. Iremos validar 3 hipóteses que possam responder a essa diferença:
#
# 1. Os magistrados de 1 grau se esforçam mais horas
# 2. Os magistrados de 1 grau possuem mais recursos que aumentam a sua produtividade como pessoal e tecnologias
#
# O  primeiro teste podemos relacionar pela carga de trabalo dos magistrados no gráfico abaixo

# %%
k_trabalho = cnj.groupby(['ano']).mean()[['k1','k2']].reset_index()
k_trabalho = pd.wide_to_long(k_trabalho,stubnames=['k'],i=['ano'],j= 'grau').reset_index()
sns.barplot(data=k_trabalho,x='ano',y='k',hue='grau')

# %%
produtividade_1grau = cnj.loc[cnj['ano'].isin([2009,2018])].pivot(index='sigla', columns='ano', values='ipm1')
produtividade_1grau["diff_1"] = (produtividade_1grau[2018] - produtividade_1grau[2009])/produtividade_1grau[2009]

produtividade_2grau = cnj.loc[cnj['ano'].isin([2009,2018])].pivot(index='sigla', columns='ano', values='ipm2')
produtividade_2grau["diff_2"] = (produtividade_2grau[2018] - produtividade_2grau[2009])/produtividade_2grau[2009]

diff = pd.merge(produtividade_1grau, produtividade_2grau, left_index=True, right_index=True,suffixes=('_1grau','_2grau'))
diff.style.bar(subset=['diff_1','diff_2'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_8735680e_b5c1_11ea_8944_20c9d08bbc0drow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.1%, #5fba7d 25.1%, #5fba7d 30.5%, transparent 30.5%);
#         }    #T_8735680e_b5c1_11ea_8944_20c9d08bbc0drow0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.8%, #5fba7d 6.8%, #5fba7d 11.3%, transparent 11.3%);
#         }    #T_8735680e_b5c1_11ea_8944_20c9d08bbc0drow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.1%, #5fba7d 25.1%, #5fba7d 71.5%, transparent 71.5%);
#         }    #T_8735680e_b5c1_11ea_8944_20c9d08bbc0drow1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.8%, #5fba7d 6.8%, #5fba7d 20.5%, transparent 20.5%);
# ...

# %%
cnj[cnj['sigla']=='TJPA'].groupby('ano').mean()['cn2'].plot()

# %%
casos_novos_1grau = cnj.loc[cnj['ano'].isin([2009,2018])].pivot(index='sigla', columns='ano', values='cn1')
casos_novos_1grau["Variação_Casos_Novos"] = (casos_novos_1grau[2018] - casos_novos_1grau[2009])/casos_novos_1grau[2009] 

diff_aumento = pd.merge(diff, casos_novos_1grau, left_index=True, right_index=True)[['diff_1','diff_2','Variação_Casos_Novos']] 
diff_aumento = diff_aumento[diff_aumento['Variação_Casos_Novos']>0]

diff_sem_aumento = pd.merge(diff, casos_novos_1grau, left_index=True, right_index=True)[['diff_1','diff_2','Variação_Casos_Novos']]
diff_sem_aumento = diff_sem_aumento[diff_sem_aumento['Variação_Casos_Novos']<=0]

diff_aumento.style.bar(subset=['diff_1','diff_2',"Variação_Casos_Novos"], align='mid', color=['#d65f5f', '#5fba7d'])
diff_sem_aumento.style.bar(subset=['diff_1',"Variação_Casos_Novos",'diff_2'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_485f04a4_b400_11ea_acd3_20c9d08bbc0drow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.1%, #5fba7d 25.1%, #5fba7d 30.5%, transparent 30.5%);
#         }    #T_485f04a4_b400_11ea_acd3_20c9d08bbc0drow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.5%, #5fba7d 5.5%, #5fba7d 10.0%, transparent 10.0%);
#         }    #T_485f04a4_b400_11ea_acd3_20c9d08bbc0drow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 99.9%, #d65f5f 99.9%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_485f04a4_b400_11ea_acd3_20c9d08bbc0drow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.1%, #5fba7d 25.1%, #5fba7d 100.0%, transparent 100.0%);
# ...

# %%
diff_aumento.style.bar(subset=['diff_1','diff_2',"Variação_Casos_Novos"], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
#     #T_54d45d72_b3ee_11ea_acd3_20c9d08bbc0drow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.2%, #5fba7d 17.2%, #5fba7d 69.9%, transparent 69.9%);
#         }    #T_54d45d72_b3ee_11ea_acd3_20c9d08bbc0drow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.8%, #5fba7d 7.8%, #5fba7d 23.3%, transparent 23.3%);
#         }    #T_54d45d72_b3ee_11ea_acd3_20c9d08bbc0drow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 24.2%, transparent 24.2%);
#         }    #T_54d45d72_b3ee_11ea_acd3_20c9d08bbc0drow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 17.2%, #5fba7d 17.2%, #5fba7d 90.1%, transparent 90.1%);
# ...

# %%
var
# Out:
#              sigla  \
# 7              ano
# 43             cn1
# 44             cn2
# 422           ipm1
# 423           ipm2
# 451        justica
# 453             k1
# 454             k2
# 491          mage1
# 492          mage2
# 529          munic
# 557         pesus1
# 558         pesus2
# 568            pib
# 570          porte
# 572        procel1
# 573        procel2
# 591          reat2
# 592         reatc1
# 600   reatextfisc1
# 692      sajudmag1
# 693      sajudmag2
# 708           scn1
# 709           scn2
# 772          sigla
# 823         tbaix1
# 824         tbaix2
# 861            tc1
# 862            tc2
# 906         tfaux1
# 907         tfaux2
# 1228  uf_abrangida
# 1229       uf_sede
#
#                                                                  dsc_sigla
# 7                                                                      Ano
# 43                                           Cn1º - Casos Novos no 1º Grau
# ...

# %%
cnj[['mage1','mage2']]
cnj.groupby(['ano','sigla']).mean()['sajudmag1']
# Out:
# ano   sigla
# 2009  TJ       12.065972
#       TJAC      6.053571
#       TJAL      9.376238
#       TJAM      5.008000
#       TJAP      9.758621
#       TJBA     16.903448
#       TJCE      7.141066
#       TJDFT    11.574163
#       TJES      9.966942
#       TJGO      8.996721
#       TJMA     12.900990
#       TJMG     14.087694
#       TJMS     11.350649
#       TJMT      9.373626
#       TJPA      7.476395
#       TJPB      8.215962
#       TJPE      8.875289
#       TJPI     10.010101
#       TJPR      3.011834
#       TJRJ     15.727434
#       TJRN     12.331522
#       TJRO     10.923077
#       TJRR     20.222222
#       TJRS      9.808099
#       TJSC     12.376506
#       TJSE     11.097561
#       TJSP     16.491881
#       TJTO      9.262626
# 2010  TJ       12.424395
#       TJAC      7.092593
#       TJAL      8.523810
#       TJAM      5.716667
#       TJAP      9.888889
#       TJBA     20.724731
#       TJCE      7.537994
#       TJDFT    14.321608
# ...

# %%
sns.barplot()

# %%
sns.heatmap(corr[['ipm1','ipm2']])

# %%
corr[['ipm1','ipm2']].sort_values('ipm1')
# Out:
#                   ipm1      ipm2
# sajudmag2    -0.278610  0.004483
# tc2          -0.234748 -0.355257
# tc1           0.035891  0.072068
# pesus1        0.084109  0.072740
# reat2         0.096254  0.126983
# procel1       0.102551  0.077663
# scn2          0.179322  0.085080
# mage1         0.195301  0.144410
# procel2       0.221592  0.129380
# tfaux2        0.230150  0.180983
# tfaux1        0.230344  0.198013
# reatc1        0.231851  0.144254
# reatextfisc1  0.238595  0.169422
# k2            0.245227  0.845321
# mage2         0.251564  0.165497
# tbaix2        0.263234  0.239583
# cn1           0.265289  0.168306
# cn2           0.269822  0.229408
# tbaix1        0.278073  0.169087
# ipm2          0.327457  1.000000
# scn1          0.352257  0.076375
# pesus2        0.375210  0.220542
# sajudmag1     0.433465  0.111389
# k1            0.784008  0.175925
# ipm1          1.000000  0.327457

# %%
plt.scatter(cnj[''],cnj[''])
#https://queirozf.com/entries/add-labels-and-text-to-matplotlib-plots-annotation-examples

# %%
cor_var = ['cn1','cn2','tbaix1','tbaix2'
              ,'mage1','mage2','ipm1','ipm2','k1','k2','pesus1','pesus2','procel1','procel2','reatc1','reat2'
              ,'reatextfisc1','sajudmag1','sajudmag2','scn1','scn2','tc1','tc2','tfaux1','tfaux2']
corr = cnj[cor_var].corr()
sns.heatmap(corr)
